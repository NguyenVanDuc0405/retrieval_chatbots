# %% [markdown]
# Q&A về tuyển sinh 2024

# %%
import pandas as pd

# Tạo dữ liệu mẫu
data = {
    'question': [],
    'answer': [],
    'tag': [],
}

# Tạo DataFrame
data_frame = pd.DataFrame(data)

# Lưu DataFrame thành file CSV
data_frame.to_csv('questions_answers.csv', index=False)

print("File CSV đã được cập nhật thành công!")
# Out:
# File CSV đã được cập nhật thành công!

# %%
df = pd.read_json('documents\\tuyensinh_2024\\cau_hoi_thuong_gap.json')
for temp in df.data:
    q1 = temp['cauHoi']
    a1 = temp['cauTraLoi']
    data['question'].append(q1)
    data['answer'].append(a1)
    data['tag'].append("tuyển sinh")
    
print("Câu hỏi:" + "\n" +df.data[0]['cauHoi'])
print("Câu trả lời:" + "\n" + df.data[0]['cauTraLoi'])
data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Nguyên tắc xét tuyển của học viện năm nay ntn? Và học viện có áp dụng tiêu chí phụ gì khi xét đối với các thí sinh đăng ký vào không?
# Câu trả lời:
# I. Xét tuyển dựa vào kết quả thi THPT 2024:
# -	Xét tuyển theo ngành và theo tổ hợp bài thi/môn thi xét tuyển;
# -	Điểm trúng tuyển của các tổ hợp bài thi/môn thi trong cùng một ngành là bằng nhau (không có điểm chênh lệch giữa các tổ hợp trong cùng một ngành);
# -	Xét trúng tuyển từ thí sinh có kết quả cao xuống và đảm bảo chất lượng tuyển sinh;
# -	Xét tuyển các nguyện vọng bình đẳng (không có điểm chênh lệch giữa các nguyện vọng trong cùng một ngành), nếu thí sinh không trúng tuyển nguyện vọng ở thứ tự ưu tiên thứ nhất (nguyện vọng 1) thì sẽ được tự động xét tuyển ở nguyện vọng ưu tiên thứ hai (nguyện vọng 2) và kế tiếp;
# -	Thí sinh chỉ trúng tuyển vào 1 nguyện vọng ưu tiên cao nhất trong danh sách các nguyện vọng đã đăng ký, khi đã trúng tuyển ở nguyện vọng nào thì không được xét tuyển tiếp ở nguyện vọng sau;
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_json('documents\\tuyensinh_2024\\hoc_bong.json')
q2 = "Học viện có bao nhiêu loại học bổng"
a2 = "Có 3 loại học bổng là: học bổng đặc biệt, học bổng toàn phần và học bổng cho thí sinh đạt thành tích cao"
data['question'].append(q2)
data['answer'].append(a2)
data['tag'].append("học bổng")
for temp in df.data:
    q3 = 'Chi tiết về loại ' + temp['loaiHocBong']
    a3 = temp['chiTiet']
    data['question'].append(q3)
    data['answer'].append(a3)
    data['tag'].append("học bổng")

    q3 = temp['loaiHocBong']
    a3 = temp['chiTiet']
    data['question'].append(q3)
    data['answer'].append(a3)
    data['tag'].append("học bổng")

print("Câu hỏi:" + "\n" +df.data[0]['loaiHocBong'])
print("Câu trả lời:" + "\n" + df.data[0]['chiTiet'])
data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# học bổng đặc biệt
# Câu trả lời:
# Năm 2024, Học viện Công nghệ Bưu chính Viễn thông cấp tối đa 30 suất học bổng đặc biệt, giá trị mỗi suất tới 500 triệu đồng cho các thí sinh xuất sắc (gồm miễn học phí toàn thời gian học, chi phí ăn ở, kinh phí nghiên cứu khoa học, thực tập ở nước ngoài, kinh phí hỗ trợ từ doanh nghiệp đối tác và các hỗ trợ khác).
# Đối tượng xét cấp học bổng đặc biệt là các thí sinh tham dự kỳ thi chọn đội tuyển quốc gia dự thi Olympic quốc tế, thí sinh đạt giải Nhất, Nhì, Ba trong kỳ thi chọn học sinh giỏi quốc gia các môn Toán, Lý và Tin học; thí sinh có điểm thi tốt nghiệp THPT từ 29,0 điểm trở lên. Ngoài ra, người được nhận học bổng còn phải đảm bảo điểm trung bình chung tích lũy năm học liên tục đạt từ loại Giỏi trở lên.
#                                              question  \
# 0   Nguyên tắc xét tuyển của học viện năm nay ntn?...
# 1                    Câu hỏi thường gặp về tuyển sinh
# 2   Chương trình đào tạo tại miền Nam có khác với ...
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_json('documents\\tuyensinh_2024\\moc_thoi_gian.json')
q4 = "Các mốc thời gian quan trọng"
a4 = ""
for temp in df.data:
    a4 = a4 + 'Mốc '+  temp['tieuDe'].lower() + " diễn ra vào: " + temp['mocThoiGian'] +"\n"
data['question'].append(q4) 
data['answer'].append(a4.rstrip())
data['tag'].append("tuyển sinh")

print("Câu hỏi:" + "\n" +q4)
print("Câu trả lời:" + "\n" + a4.rstrip())

for temp in df.data:
    q5 = 'Mốc ' + temp['tieuDe'].lower() + " diễn ra vào thời gian nào?"
    a5 = 'Mốc ' + temp['tieuDe'].lower() + " diễn ra vào: " + temp['mocThoiGian']
    data['question'].append(q5)
    data['answer'].append(a5)
    data['tag'].append("tuyển sinh")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Các mốc thời gian quan trọng
# Câu trả lời:
# Mốc thí sinh đăng ký, điều chỉnh nguyện vọng xét tuyển diễn ra vào: 2024-07-10
# Mốc nộp lệ phí xét tuyển trực tuyến diễn ra vào: 2024-07-28
# Mốc thông báo thí sinh trúng tuyển đợt 1 diễn ra vào: 2024-08-12
# Mốc hoàn thành xác nhận nhập học trực tuyến đợt 1 trên hệ thống diễn ra vào: 2024-08-18
#                                              question  \
# 0   Nguyên tắc xét tuyển của học viện năm nay ntn?...
# 1                    Câu hỏi thường gặp về tuyển sinh
# 2   Chương trình đào tạo tại miền Nam có khác với ...
# 3   Trường mình có 2 cơ sở, vậy sẽ phân bố học sin...
# 4   Em đăng ký NV1 là ngành An toàn thông tin, NV2...
# 5                 Học viện có bao nhiêu loại học bổng
# 6                  Chi tiết về loại học bổng đặc biệt
# 7                                   học bổng đặc biệt
# 8   Chi tiết về loại học bổng cho thí sinh đạt thà...
# 9            học bổng cho thí sinh đạt thành tích cao
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_json('documents\\tuyensinh_2024\\phuong_thuc_xet_tuyen.json')
q7 = "Các phương thức xét tuyển của học viện?"
a7 =""
for temp in df.data:
    a7 = a7 + temp['tieuDe'].split("-")[1] +"\n"
data['question'].append(q7) 
data['answer'].append(a7.rstrip())
data['tag'].append("tuyển sinh")

print("Câu hỏi:" + "\n" +q7)
print("Câu trả lời:" + "\n" + a7.rstrip())

for temp in df.data:
    q8 = 'Chi tiết về phương thức' + temp['tieuDe'].split("-")[1] +"?"
    a8 =""
    for i in temp['contents']:
        a8 = a8 + i +"\n"
        
    print("Câu hỏi:" + "\n" +q8)
    print("Câu trả lời:" + "\n" + a8.rstrip() )
    data['question'].append(q8)
    data['answer'].append(a8.rstrip())
    data['tag'].append("tuyển sinh")


data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Các phương thức xét tuyển của học viện?
# Câu trả lời:
#  Xét tuyển tài năng
#  Xét tuyển dựa vào kết quả thi THPT
#  Xét tuyển kết hợp
#  Xét tuyển dựa vào kết quả thi đánh giá năng lực
#  Xét tuyển dựa vào kết quả thi đánh giá tư duy
# Câu hỏi:
# Chi tiết về phương thức Xét tuyển tài năng?
# Câu trả lời:
# Xét tuyển thẳng và ưu tiên xét tuyển: Học viện thực hiện xét tuyển thẳng và ưu tiên xét tuyển theo Quy chế tuyển sinh đại học của Bộ Giáo dục và Đào tạo (có thông báo chi tiết riêng)
# Xét tuyển dựa vào hồ sơ năng lực đối với các thí sinh có Thành tích đoạt giải trong kỳ thi chọn học sinh giỏi THPT cấp quốc gia (giải Khuyến khích), cấp Tỉnh/Thành phố trực thuộc TW (Nhất, Nhì, Ba và Khuyến khích), thời gian đoạt giải không quá 3 năm tính tới thời điểm xét tuyển hoặc là học sinh tại các trường THPT chuyên.
# Câu hỏi:
# Chi tiết về phương thức Xét tuyển dựa vào kết quả thi THPT?
# Câu trả lời:
# Xét tuyển theo ngành và theo tổ hợp bài thi/môn thi xét tuyển
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_json('documents\\tuyensinh_2024\\quy_trinh_xet_tuyen.json')
q9 = "Quy trình nộp hồ sơ trực tuyến như nào?"
a9 =""
for temp in df.data:
    a9 = a9 + temp['tieuDe'] + "\n"
data['question'].append(q9) 
data['answer'].append(a9.rstrip())
data['tag'].append("tuyển sinh")
print("Câu hỏi:" + "\n" +q9)
print("Câu trả lời:" + "\n" + a9.rstrip())

for temp in df.data:
    q10 = 'Chi tiết về ' + temp['tieuDe']+ "?"
    a10 = temp['chiTiet']
    print("Câu hỏi:" + "\n" +q10)
    print("Câu trả lời:" + "\n" + a10 )
    data['question'].append(q10)
    data['answer'].append(a10)
    data['tag'].append("tuyển sinh")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Quy trình nộp hồ sơ trực tuyến như nào?
# Câu trả lời:
# B1: Đăng ký tài khoản
# B2: Khai báo thông tin
# B3: Đăng ký nguyện vọng
# B4: Thanh toán trực tuyến
# B5: Nộp hồ sơ về Học viện
# B6: Nhận thông tin kết quả
# Câu hỏi:
# Chi tiết về B1: Đăng ký tài khoản?
# Câu trả lời:
# Đăng ký tài khoản trên hệ thống https://xettuyen.ptit.edu.vn với địa chỉ email hoặc tài khoản Google, Facebook
# Câu hỏi:
# Chi tiết về B2: Khai báo thông tin?
# Câu trả lời:
# Thí sinh thực hiện khai báo hồ sơ xét tuyển theo Đề án tuyển sinh của Học viện với 3 phương thức xét tuyển: Xét tuyển tài năng, Xét tuyển kết hợp, Xét tuyển dựa vào kết quả bài thi đánh giá năng lực hoặc đánh giá tư duy.
# Câu hỏi:
# Chi tiết về B3: Đăng ký nguyện vọng?
# Câu trả lời:
# Thí sinh thực hiện đăng ký nguyện vọng xét tuyển trên hệ thống. Mỗi thí sinh được đăng ký tối đa 2 nguyện vọng.
# Câu hỏi:
# Chi tiết về B4: Thanh toán trực tuyến?
# Câu trả lời:
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_json('documents\\tuyensinh_2024\\chi_tieu_BVH_ver2.json')

for temp in df.data:
    q6 = temp['nganhHoc']['tenNganh'] + " xét tuyển theo tổ hợp nào?"
    a6 = temp['nganhHoc']['tenNganh'] + " xét tuyển theo tổ hợp: "
    for i in temp['nganhHoc']['toHop']:
        a6 = a6 + i +" "
    print("Câu hỏi:" + "\n" +q6)
    print("Câu trả lời:" + "\n" + a6)
    data['question'].append(q6)
    data['answer'].append(a6)
    data['tag'].append("ngành đào tạo")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Ngành Công nghệ thông tin xét tuyển theo tổ hợp nào?
# Câu trả lời:
# Ngành Công nghệ thông tin xét tuyển theo tổ hợp: A00 A01
# Câu hỏi:
# Ngành An toàn thông tin xét tuyển theo tổ hợp nào?
# Câu trả lời:
# Ngành An toàn thông tin xét tuyển theo tổ hợp: A00 A01
# Câu hỏi:
# Ngành Kỹ thuật Điện tử viễn thông xét tuyển theo tổ hợp nào?
# Câu trả lời:
# Ngành Kỹ thuật Điện tử viễn thông xét tuyển theo tổ hợp: A00 A01
# Câu hỏi:
# Ngành Công nghệ kỹ thuật Điện điện tử xét tuyển theo tổ hợp nào?
# Câu trả lời:
# Ngành Công nghệ kỹ thuật Điện điện tử xét tuyển theo tổ hợp: A00 A01
# Câu hỏi:
# Ngành Công nghệ đa phương tiện xét tuyển theo tổ hợp nào?
# Câu trả lời:
# Ngành Công nghệ đa phương tiện xét tuyển theo tổ hợp: A00 A01 D01
# Câu hỏi:
# Ngành Truyền thông đa phương tiện xét tuyển theo tổ hợp nào?
# Câu trả lời:
# Ngành Truyền thông đa phương tiện xét tuyển theo tổ hợp: A00 A01 D01
# Câu hỏi:
# Ngành Marketing xét tuyển theo tổ hợp nào?
# Câu trả lời:
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_json('documents\\tuyensinh_2024\\chi_tieu_BVS.json')

for temp in df.data:
    q6 = temp['nganhHoc']['tenNganh'] + " xét tuyển theo tổ hợp nào?"
    a6 = temp['nganhHoc']['tenNganh'] + " xét tuyển theo tổ hợp: "
    for i in temp['nganhHoc']['toHop']:
        a6 = a6 + i +" "
    print("Câu hỏi:" + "\n" +q6)
    print("Câu trả lời:" + "\n" + a6)
    data['question'].append(q6)
    data['answer'].append(a6)
    data['tag'].append("ngành đào tạo")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Ngành Công nghệ thông tin xét tuyển theo tổ hợp nào?
# Câu trả lời:
# Ngành Công nghệ thông tin xét tuyển theo tổ hợp: A00 A01
# Câu hỏi:
# Ngành An toàn thông tin xét tuyển theo tổ hợp nào?
# Câu trả lời:
# Ngành An toàn thông tin xét tuyển theo tổ hợp: A00 A01
# Câu hỏi:
# Ngành Công nghệ kỹ thuật Điện điện tử xét tuyển theo tổ hợp nào?
# Câu trả lời:
# Ngành Công nghệ kỹ thuật Điện điện tử xét tuyển theo tổ hợp: A00 A01
# Câu hỏi:
# Ngành Kỹ thuật Điện tử viễn thông xét tuyển theo tổ hợp nào?
# Câu trả lời:
# Ngành Kỹ thuật Điện tử viễn thông xét tuyển theo tổ hợp: A00 A01
# Câu hỏi:
# Ngành Công nghệ đa phương tiện xét tuyển theo tổ hợp nào?
# Câu trả lời:
# Ngành Công nghệ đa phương tiện xét tuyển theo tổ hợp: A00 A01 D01
# Câu hỏi:
# Ngành Marketing xét tuyển theo tổ hợp nào?
# Câu trả lời:
# Ngành Marketing xét tuyển theo tổ hợp: A00 A01 D01
# Câu hỏi:
# Ngành Quản trị kinh doanh xét tuyển theo tổ hợp nào?
# Câu trả lời:
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_json('documents\\tuyensinh_2024\\chi_tieu_BVH_ver2.json')
q = "Học viện đào tạo những ngành nào ở cơ sở miền bắc năm 2024?"
a = "Miền bắc Học Viện hiện tại đào tạo các ngành như:\n"
for temp in df.data:
    a = a + temp['nganhHoc']['tenNganh'] +'\n'

    q111 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'] + " năm 2024 là bao nhiêu?"
    a111 = "Bạn muốn hỏi chỉ tiêu dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, xét tuyển tài năng, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("ngành đào tạo")
    
    q112 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'] + " là bao nhiêu?"
    a112 = "Bạn muốn hỏi chỉ tiêu dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, xét tuyển tài năng, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q112)
    data['answer'].append(a112)
    data['tag'].append("ngành đào tạo")

    q11 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức thi thpt tại cơ sở miền bắc là bao nhiêu?"
    a11 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức thi thpt tại cơ sở miền bắc là: " + str(temp['chiTieuTheoKetQuaThiTHPT'])
    print("Câu hỏi:" + "\n" +q11)
    print("Câu trả lời:" + "\n" + a11)
    data['question'].append(q11)
    data['answer'].append(a11)
    data['tag'].append("ngành đào tạo")

    q12 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức xét tuyển kết hợp tại cơ sở miền bắc là bao nhiêu?"
    a12 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức xét tuyển kết hợp tại cơ sở miền bắc là: " + str(temp['chiTieuTheoPhuongThucKetHop'])
    data['question'].append(q12)
    data['answer'].append(a12)
    data['tag'].append("ngành đào tạo")

    q13 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức xét tuyển tài năng tại cơ sở miền bắc là bao nhiêu?"
    a13 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức xét tuyển tài năng tại cơ sở miền bắc là: " + str(temp['chiTieuTheoXetTuyenTaiNang'])
    data['question'].append(q13)
    data['answer'].append(a13)
    data['tag'].append("ngành đào tạo")

    q14 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức thi đánh giá năng lực tại cơ sở miền bắc là bao nhiêu?"
    a14 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức thi đánh giá năng lực tại cơ sở miền bắc là: " + str(temp['chiTieuTheoDGNL'])
    data['question'].append(q14)
    data['answer'].append(a14)
    data['tag'].append("ngành đào tạo")

    q15 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức thi đánh giá tư duy tại cơ sở miền bắc là bao nhiêu?"
    a15 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức thi đánh giá tư duy tại cơ sở miền bắc là: " + str(temp['chiTieuTheoDGNL'])
    data['question'].append(q15)
    data['answer'].append(a15)
    data['tag'].append("ngành đào tạo")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")

q1 = "Học viện đào tạo những ngành nào ở cơ sở miền bắc?"
data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")

q1 = "Tôi muốn tìm hiểu các ngành ở cơ sở miền bắc?"
data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")

q1 = "Miền bắc đào tạo những ngành nào?"
data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")

q1 = "Cơ sở miền bắc đào tạo những ngành nào?"
data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")

q1 = "Học viện đào tạo những ngành nào năm 2024?"
a1 = "Bạn muốn hỏi ở cơ sở miền Bắc hay miền Nam của Học Viện?"
data['question'].append(q1)
data['answer'].append(a1.rstrip())
data['tag'].append("ngành đào tạo")

q1 = "Tôi muốn tìm hiểu về các ngành học của học viện?"
data['question'].append(q1)
data['answer'].append(a1.rstrip())
data['tag'].append("ngành đào tạo")

q1 = "Học viện đào tạo những ngành nào?"
data['question'].append(q1)
data['answer'].append(a1.rstrip())
data['tag'].append("ngành đào tạo")

q1 = "Các ngành đang đào tạo?"
data['question'].append(q1)
data['answer'].append(a1.rstrip())
data['tag'].append("ngành đào tạo")


data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Chỉ tiêu của ngành công nghệ thông tin theo phương thức thi thpt tại cơ sở miền bắc là bao nhiêu?
# Câu trả lời:
# Chỉ tiêu của ngành công nghệ thông tin theo phương thức thi thpt tại cơ sở miền bắc là: 300
# Câu hỏi:
# Chỉ tiêu của ngành an toàn thông tin theo phương thức thi thpt tại cơ sở miền bắc là bao nhiêu?
# Câu trả lời:
# Chỉ tiêu của ngành an toàn thông tin theo phương thức thi thpt tại cơ sở miền bắc là: 140
# Câu hỏi:
# Chỉ tiêu của ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt tại cơ sở miền bắc là bao nhiêu?
# Câu trả lời:
# Chỉ tiêu của ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt tại cơ sở miền bắc là: 195
# Câu hỏi:
# Chỉ tiêu của ngành công nghệ kỹ thuật điện điện tử theo phương thức thi thpt tại cơ sở miền bắc là bao nhiêu?
# Câu trả lời:
# Chỉ tiêu của ngành công nghệ kỹ thuật điện điện tử theo phương thức thi thpt tại cơ sở miền bắc là: 170
# Câu hỏi:
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_json('documents\\tuyensinh_2024\\chi_tieu_BVS.json')
q = "Học viện đào tạo những ngành nào ở cơ sở miền nam năm 2024?"
a = "Miền nam Học Viện hiện tại đào tạo các ngành như:\n"

for temp in df.data:
    a = a + temp['nganhHoc']['tenNganh'] +'\n'  

    q111 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'] + " năm 2024 là bao nhiêu?"
    a111 = "Bạn muốn hỏi chỉ tiêu dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, xét tuyển tài năng, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("ngành đào tạo")
    q112 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'] + " là bao nhiêu?"
    a112 = "Bạn muốn hỏi chỉ tiêu dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, xét tuyển tài năng, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q112)
    data['answer'].append(a112)
    data['tag'].append("ngành đào tạo")
    q11 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức thi thpt tại cơ sở miền nam là bao nhiêu?"
    a11 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức thi thpt tại cơ sở miền nam là: " + str(temp['chiTieuTheoKetQuaThiTHPT'])
    print("Câu hỏi:" + "\n" +q11)
    print("Câu trả lời:" + "\n" + a11)
    data['question'].append(q11)
    data['answer'].append(a11)
    data['tag'].append("ngành đào tạo")
    q12 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'] + " theo phương thức xét tuyển kết hợp tại cơ sở miền nam là bao nhiêu?"
    a12 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức xét tuyển kết hợp tại cơ sở miền nam là: " + str(temp['chiTieuTheoPhuongThucKetHop'])
    data['question'].append(q12)
    data['answer'].append(a12)
    data['tag'].append("ngành đào tạo")

    q13 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'] + " theo phương thức xét tuyển tài năng tại cơ sở miền nam là bao nhiêu?"
    a13 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức xét tuyển tài năng tại cơ sở miền nam là: " + str(temp['chiTieuTheoXetTuyenTaiNang'])
    data['question'].append(q13)
    data['answer'].append(a13)
    data['tag'].append("ngành đào tạo")

    q14 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'] + " theo phương thức thi đánh giá năng lực tại cơ sở miền nam là bao nhiêu?"
    a14 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức thi đánh giá năng lực tại cơ sở miền nam là: " + str(temp['chiTieuTheoDGNL'])
    data['question'].append(q14)
    data['answer'].append(a14)
    data['tag'].append("ngành đào tạo")

    q15 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'] + " theo phương thức thi đánh giá tư duy tại cơ sở miền nam là bao nhiêu?"
    a15 = "Chỉ tiêu của " + temp['nganhHoc']['tenNganh'].lower() + " theo phương thức thi đánh giá tư duy tại cơ sở miền nam là: " + str(temp['chiTieuTheoDGNL'])
    data['question'].append(q15)
    data['answer'].append(a15)
    data['tag'].append("ngành đào tạo")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")
q1 = "Đào tạo những ngành nào ở cơ sở miền nam năm 2024?"
data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")
q1 = "Tôi muốn tìm hiểu các ngành ở cơ sở miền nam?"
data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")
q1 = "Đào tạo những ngành nào ở cơ sở miền nam?"
data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")
q1 = "Miền nam đào tạo những ngành nào?"
data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")
data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Chỉ tiêu của ngành công nghệ thông tin theo phương thức thi thpt tại cơ sở miền nam là bao nhiêu?
# Câu trả lời:
# Chỉ tiêu của ngành công nghệ thông tin theo phương thức thi thpt tại cơ sở miền nam là: 90
# Câu hỏi:
# Chỉ tiêu của ngành an toàn thông tin theo phương thức thi thpt tại cơ sở miền nam là bao nhiêu?
# Câu trả lời:
# Chỉ tiêu của ngành an toàn thông tin theo phương thức thi thpt tại cơ sở miền nam là: 40
# Câu hỏi:
# Chỉ tiêu của ngành công nghệ kỹ thuật điện điện tử theo phương thức thi thpt tại cơ sở miền nam là bao nhiêu?
# Câu trả lời:
# Chỉ tiêu của ngành công nghệ kỹ thuật điện điện tử theo phương thức thi thpt tại cơ sở miền nam là: 45
# Câu hỏi:
# Chỉ tiêu của ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt tại cơ sở miền nam là bao nhiêu?
# Câu trả lời:
# Chỉ tiêu của ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt tại cơ sở miền nam là: 50
# Câu hỏi:
# ...

# %% [markdown]
# Q&A tổng quan về các ngành

# %%
ids = [
    "7480201_UDU",
    "7480101",
    "7480201",
    "7480202",
    "7520207",
    "7510301",
    "7329001",
    "7320104",
    "7340115",
    "7340122",
    "7340101",
    "7340301",
    "7340202",
    "7480201(CLC)",
    "7340208",
    "7480205",
    "7520216",
    "7320101",
    "7340205",
    "7480102",
    "7340115_CLC",
    "7520208",
    "734030",
    "7329001_GAM",
    "7480201_VNH"
]
import pandas as pd
import os
import json
# Đường dẫn tới thư mục chứa các file JSON
directory = 'documents\\tong_quan_ve_nganh'

# Lặp qua từng id và đọc file JSON tương ứng
for id in ids:
    filename = os.path.join(directory, f"{id}.json")
    if os.path.isfile(filename):
        with open(filename, 'r', encoding='utf-8') as file:
            datajson = json.load(file)
            q15 = "Mã ngành của " + datajson['titleMajor'] +" là bao nhiêu?"
            a15 = datajson['titleMajor'] + " có mã ngành là: " + datajson['maNganh']
            print("Câu hỏi:" + "\n" +q15)
            print("Câu trả lời:" + "\n" + a15)
            data['question'].append(q15)
            data['answer'].append(a15)
            data['tag'].append("ngành đào tạo")
            
    else:
        print(f"File {filename} không tồn tại.")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Mã ngành của Chương trình Công nghệ thông tin (định hướng ứng dụng) là bao nhiêu?
# Câu trả lời:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) có mã ngành là: 7480201_UDU
# Câu hỏi:
# Mã ngành của Ngành Khoa học máy tính là bao nhiêu?
# Câu trả lời:
# Ngành Khoa học máy tính có mã ngành là: 7480101
# Câu hỏi:
# Mã ngành của Ngành Công nghệ thông tin là bao nhiêu?
# Câu trả lời:
# Ngành Công nghệ thông tin có mã ngành là: 7480201
# Câu hỏi:
# Mã ngành của Ngành An toàn thông tin là bao nhiêu?
# Câu trả lời:
# Ngành An toàn thông tin có mã ngành là: 7480202
# Câu hỏi:
# Mã ngành của Ngành Kỹ thuật Điện tử viễn thông là bao nhiêu?
# Câu trả lời:
# Ngành Kỹ thuật Điện tử viễn thông có mã ngành là: 7520207
# Câu hỏi:
# Mã ngành của Ngành Công nghệ kỹ thuật Điện, điện tử là bao nhiêu?
# Câu trả lời:
# Ngành Công nghệ kỹ thuật Điện, điện tử có mã ngành là: 7510301
# Câu hỏi:
# Mã ngành của Ngành Công nghệ đa phương tiện là bao nhiêu?
# Câu trả lời:
# ...

# %%
# Lặp qua từng id và đọc file JSON tương ứng
for id in ids:
    filename = os.path.join(directory, f"{id}.json")
    if os.path.isfile(filename):
        with open(filename, 'r', encoding='utf-8') as file:
            datajson = json.load(file)
            q16 = "Thời gian học của " + datajson['titleMajor'] +" là bao lâu?"
            a16 = datajson['titleMajor'] + " có thời gian học là: " + datajson['thoigianHoc']
            print("Câu hỏi:" + "\n" +q16)
            print("Câu trả lời:" + "\n" + a16)
            data['question'].append(q16)
            data['answer'].append(a16)
            data['tag'].append("ngành đào tạo")

            q16 = "Thời gian đào tạo của " + datajson['titleMajor'] +" là bao lâu?"
            a16 = datajson['titleMajor'] + " có thời gian học là: " + datajson['thoigianHoc']
            print("Câu hỏi:" + "\n" +q16)
            print("Câu trả lời:" + "\n" + a16)
            data['question'].append(q16)
            data['answer'].append(a16)
            data['tag'].append("ngành đào tạo")

            q16 = datajson['titleMajor'] +" học bao lâu?"
            a16 = datajson['titleMajor'] + " có thời gian học là: " + datajson['thoigianHoc']
            print("Câu hỏi:" + "\n" +q16)
            print("Câu trả lời:" + "\n" + a16)
            data['question'].append(q16)
            data['answer'].append(a16)
            data['tag'].append("ngành đào tạo")

            q16 = "Số năm đào tạo của " + datajson['titleMajor'] +" là bao lâu?"
            a16 = datajson['titleMajor'] + " có thời gian học là: " + datajson['thoigianHoc']
            print("Câu hỏi:" + "\n" +q16)
            print("Câu trả lời:" + "\n" + a16)
            data['question'].append(q16)
            data['answer'].append(a16)
            data['tag'].append("ngành đào tạo")

            q16 = "Số năm học của " + datajson['titleMajor'] +" là bao lâu?"
            a16 = datajson['titleMajor'] + " có thời gian học là: " + datajson['thoigianHoc']
            print("Câu hỏi:" + "\n" +q16)
            print("Câu trả lời:" + "\n" + a16)
            data['question'].append(q16)
            data['answer'].append(a16)
            data['tag'].append("ngành đào tạo")
    else:
        print(f"File {filename} không tồn tại.")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Thời gian học của Chương trình Công nghệ thông tin (định hướng ứng dụng) là bao lâu?
# Câu trả lời:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) có thời gian học là: 4 năm
# Câu hỏi:
# Thời gian đào tạo của Chương trình Công nghệ thông tin (định hướng ứng dụng) là bao lâu?
# Câu trả lời:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) có thời gian học là: 4 năm
# Câu hỏi:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) học bao lâu?
# Câu trả lời:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) có thời gian học là: 4 năm
# Câu hỏi:
# Số năm đào tạo của Chương trình Công nghệ thông tin (định hướng ứng dụng) là bao lâu?
# Câu trả lời:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) có thời gian học là: 4 năm
# Câu hỏi:
# Số năm học của Chương trình Công nghệ thông tin (định hướng ứng dụng) là bao lâu?
# Câu trả lời:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) có thời gian học là: 4 năm
# Câu hỏi:
# ...

# %%
# Lặp qua từng id và đọc file JSON tương ứng
for id in ids:
    filename = os.path.join(directory, f"{id}.json")
    if os.path.isfile(filename):
        with open(filename, 'r', encoding='utf-8') as file:
            datajson = json.load(file)
            q17 = "Thời gian nào " + datajson['titleMajor'] +" bắt đầu nhập học?"
            a17 = datajson['titleMajor'] + " có thời gian nhập học bắt đầu từ: " + datajson['kyNhapHoc']
            print("Câu hỏi:" + "\n" +q17)
            print("Câu trả lời:" + "\n" + a17)
            data['question'].append(q17)
            data['answer'].append(a17)
            data['tag'].append("ngành đào tạo")
    else:
        print(f"File {filename} không tồn tại.")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Thời gian nào Chương trình Công nghệ thông tin (định hướng ứng dụng) bắt đầu nhập học?
# Câu trả lời:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) có thời gian nhập học bắt đầu từ: Mùa thu
# Câu hỏi:
# Thời gian nào Ngành Khoa học máy tính bắt đầu nhập học?
# Câu trả lời:
# Ngành Khoa học máy tính có thời gian nhập học bắt đầu từ: Mùa thu
# Câu hỏi:
# Thời gian nào Ngành Công nghệ thông tin bắt đầu nhập học?
# Câu trả lời:
# Ngành Công nghệ thông tin có thời gian nhập học bắt đầu từ: Mùa thu
# Câu hỏi:
# Thời gian nào Ngành An toàn thông tin bắt đầu nhập học?
# Câu trả lời:
# Ngành An toàn thông tin có thời gian nhập học bắt đầu từ: Mùa thu
# Câu hỏi:
# Thời gian nào Ngành Kỹ thuật Điện tử viễn thông bắt đầu nhập học?
# Câu trả lời:
# Ngành Kỹ thuật Điện tử viễn thông có thời gian nhập học bắt đầu từ: Mùa thu
# Câu hỏi:
# Thời gian nào Ngành Công nghệ kỹ thuật Điện, điện tử bắt đầu nhập học?
# Câu trả lời:
# ...

# %%
# Lặp qua từng id và đọc file JSON tương ứng
for id in ids:
    filename = os.path.join(directory, f"{id}.json")
    if os.path.isfile(filename):
        with open(filename, 'r', encoding='utf-8') as file:
            datajson = json.load(file)
            q18 = datajson['titleMajor'] +" được đào tạo ở cơ sở nào?"
            a18 = datajson['titleMajor'] + " được đào tạo ở cơ sở " + datajson['coSo']
            print("Câu hỏi:" + "\n" +q18)
            print("Câu trả lời:" + "\n" + a18)
            data['question'].append(q18)
            data['answer'].append(a18)
            data['tag'].append("ngành đào tạo")

            q19 = datajson['titleMajor'] +" được đào tạo ở cơ sở miền bắc không?"
            a19 = datajson['titleMajor'] + " được đào tạo ở cơ sở " + datajson['coSo']
            data['question'].append(q19)
            data['answer'].append(a19)
            data['tag'].append("ngành đào tạo")

            q20 = datajson['titleMajor'] +" được đào tạo ở cơ sở miền nam không?"
            a20 = datajson['titleMajor'] + " được đào tạo ở cơ sở " + datajson['coSo']
            data['question'].append(q20)
            data['answer'].append(a20)
            data['tag'].append("ngành đào tạo")
    else:
        print(f"File {filename} không tồn tại.")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) được đào tạo ở cơ sở nào?
# Câu trả lời:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) được đào tạo ở cơ sở Hà Nội
# Câu hỏi:
# Ngành Khoa học máy tính được đào tạo ở cơ sở nào?
# Câu trả lời:
# Ngành Khoa học máy tính được đào tạo ở cơ sở Hà Nội
# Câu hỏi:
# Ngành Công nghệ thông tin được đào tạo ở cơ sở nào?
# Câu trả lời:
# Ngành Công nghệ thông tin được đào tạo ở cơ sở Hà Nội và Tp Hồ Chí Minh
# Câu hỏi:
# Ngành An toàn thông tin được đào tạo ở cơ sở nào?
# Câu trả lời:
# Ngành An toàn thông tin được đào tạo ở cơ sở Hà Nội và Tp Hồ Chí Minh
# Câu hỏi:
# Ngành Kỹ thuật Điện tử viễn thông được đào tạo ở cơ sở nào?
# Câu trả lời:
# Ngành Kỹ thuật Điện tử viễn thông được đào tạo ở cơ sở Hà Nội và Tp Hồ Chí Minh
# Câu hỏi:
# Ngành Công nghệ kỹ thuật Điện, điện tử được đào tạo ở cơ sở nào?
# Câu trả lời:
# Ngành Công nghệ kỹ thuật Điện, điện tử được đào tạo ở cơ sở Hà Nội và Tp Hồ Chí Minh
# Câu hỏi:
# ...

# %%
# Lặp qua từng id và đọc file JSON tương ứng
for id in ids:
    filename = os.path.join(directory, f"{id}.json")
    if os.path.isfile(filename):
        with open(filename, 'r', encoding='utf-8') as file:
            datajson = json.load(file)
            q19 = "Học phí của " + datajson['titleMajor'] +" là bao nhiêu?"
            a19 = datajson['titleMajor'] + " có " + datajson['hocPhi'].lower()
            print("Câu hỏi:" + "\n" +q19)
            print("Câu trả lời:" + "\n" + a19)
            data['question'].append(q19)
            data['answer'].append(a19)
            data['tag'].append("học phí")

            q19 = "Học phí " + datajson['titleMajor'] +" là bao nhiêu?"
            a19 = datajson['titleMajor'] + " có " + datajson['hocPhi'].lower()
            print("Câu hỏi:" + "\n" +q19)
            print("Câu trả lời:" + "\n" + a19)
            data['question'].append(q19)
            data['answer'].append(a19)
            data['tag'].append("học phí")
            

            q19 = "Học phí của " + datajson['titleMajor'] +" năm 2024 là bao nhiêu?"
            a19 = datajson['titleMajor'] + " có " + datajson['hocPhi'].lower()
            print("Câu hỏi:" + "\n" +q19)
            print("Câu trả lời:" + "\n" + a19)
            data['question'].append(q19)
            data['answer'].append(a19)
            data['tag'].append("học phí")

    else:
        print(f"File {filename} không tồn tại.")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Câu hỏi:
# Học phí của Chương trình Công nghệ thông tin (định hướng ứng dụng) là bao nhiêu?
# Câu trả lời:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) có học phí 900.000/1 tín chỉ
# Câu hỏi:
# Học phí Chương trình Công nghệ thông tin (định hướng ứng dụng) là bao nhiêu?
# Câu trả lời:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) có học phí 900.000/1 tín chỉ
# Câu hỏi:
# Học phí của Chương trình Công nghệ thông tin (định hướng ứng dụng) năm 2024 là bao nhiêu?
# Câu trả lời:
# Chương trình Công nghệ thông tin (định hướng ứng dụng) có học phí 900.000/1 tín chỉ
# Câu hỏi:
# Học phí của Ngành Khoa học máy tính là bao nhiêu?
# Câu trả lời:
# Ngành Khoa học máy tính có học phí theo tín chỉ năm 2024: 880.000 đ/tín chỉ.
# Câu hỏi:
# Học phí Ngành Khoa học máy tính là bao nhiêu?
# Câu trả lời:
# Ngành Khoa học máy tính có học phí theo tín chỉ năm 2024: 880.000 đ/tín chỉ.
# Câu hỏi:
# Học phí của Ngành Khoa học máy tính năm 2024 là bao nhiêu?
# Câu trả lời:
# ...

# %% [markdown]
# Q&A về điểm

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2023/BVH/THPT.csv')
q = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2023 tại cơ sở miền bắc?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2023 tại cơ sở miền bắc là:\n"
for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " năm 2023 là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")
    

    q20 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2023 tại cơ sở miền bắc là bao nhiêu?"
    a20 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2023 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    print(q20)
    print(a20)
    data['question'].append(q20)
    data['answer'].append(a20)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

q1 = "Điểm chuẩn tất cả các ngành năm 2023?"
a1 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
data['question'].append(q1)
data['answer'].append(a1.rstrip())
data['tag'].append("điểm")

q2 = "Điểm chuẩn tất cả các ngành năm 2022?"
a2 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
data['question'].append(q2)
data['answer'].append(a2.rstrip())
data['tag'].append("điểm")

q3 = "Điểm chuẩn tất cả các ngành năm 2021?"
a3 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt."
data['question'].append(q3)
data['answer'].append(a3.rstrip())
data['tag'].append("điểm")

q4 = "Điểm chuẩn tất cả các ngành năm 2024?"
a4 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
data['question'].append(q4)
data['answer'].append(a4.rstrip())
data['tag'].append("điểm")

q4 = "Điểm chuẩn tất cả các ngành?"
a4 = "Bạn muốn hỏi điểm chuẩn của năm nào, dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
data['question'].append(q4)
data['answer'].append(a4.rstrip())
data['tag'].append("điểm")

q4 = "Điểm chuẩn các ngành của học viện?"
a4 = "Bạn muốn hỏi điểm chuẩn của năm nào, dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
data['question'].append(q4)
data['answer'].append(a4.rstrip())
data['tag'].append("điểm")

q4 = "Các ngành và điểm chuẩn tại cơ sở miền bắc?"
a4 = "Bạn muốn hỏi điểm chuẩn của năm nào, dựa trên phương thức xét tuyển nào? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
data['question'].append(q4)
data['answer'].append(a4.rstrip())
data['tag'].append("điểm")

q4 = "Các ngành và điểm chuẩn tại cơ sở miền nam?"
a4 = "Bạn muốn hỏi điểm chuẩn của năm nào, dựa trên phương thức xét tuyển nào? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
data['question'].append(q4)
data['answer'].append(a4.rstrip())
data['tag'].append("điểm")

q4 = "Điểm chuẩn của ngành công nghệ thông tin và an toàn thông tin là bao nhiêu?"
a4 = "Bạn vui lòng hỏi riêng từng ngành một!"
data['question'].append(q4)
data['answer'].append(a4.rstrip())
data['tag'].append("điểm")

q4 = "Điểm chuẩn của ngành công nghệ thông tin và an toàn thông tin năm 2024 là bao nhiêu?"
a4 = "Bạn vui lòng hỏi riêng từng ngành một!"
data['question'].append(q4)
data['answer'].append(a4.rstrip())
data['tag'].append("điểm")

q4 = "Điểm chuẩn của ngành công nghệ thông tin và an toàn thông tin năm 2023 là bao nhiêu?"
a4 = "Bạn vui lòng hỏi riêng từng ngành một!"
data['question'].append(q4)
data['answer'].append(a4.rstrip())
data['tag'].append("điểm")

q4 = "Điểm chuẩn của ngành công nghệ thông tin và an toàn thông tin năm 2022 là bao nhiêu?"
a4 = "Bạn vui lòng hỏi riêng từng ngành một!"
data['question'].append(q4)
data['answer'].append(a4.rstrip())
data['tag'].append("điểm")

q4 = "Điểm chuẩn của ngành công nghệ thông tin và an toàn thông tin năm 2021 là bao nhiêu?"
a4 = "Bạn vui lòng hỏi riêng từng ngành một!"
data['question'].append(q4)
data['answer'].append(a4.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2023 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2023 tại cơ sở miền bắc là 25.68
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2023 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2023 tại cơ sở miền bắc là 25.01
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi thpt năm 2023 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi thpt năm 2023 tại cơ sở miền bắc là 25.4
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi thpt năm 2023 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi thpt năm 2023 tại cơ sở miền bắc là 26.59
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2022/BVH/THPT.csv')
q21 = ""
a21 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2022 tại cơ sở miền bắc?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2022 tại cơ sở miền bắc là:\n"

for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " năm 2022 là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")

        
    q21 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2022 tại cơ sở miền bắc là bao nhiêu?"
    a21 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2022 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    print(q21)
    print(a21)
    data['question'].append(q21)
    data['answer'].append(a21)
    data['tag'].append("điểm")

   
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2022 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2022 tại cơ sở miền bắc là 25.6
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2022 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2022 tại cơ sở miền bắc là 25.1
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi thpt năm 2022 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi thpt năm 2022 tại cơ sở miền bắc là 27.25
# Điểm chuẩn ngành an toàn thông tin theo phương thức thi thpt năm 2022 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành an toàn thông tin theo phương thức thi thpt năm 2022 tại cơ sở miền bắc là 26.7
# Điểm chuẩn ngành khoa học máy tính theo phương thức thi thpt năm 2022 tại cơ sở miền bắc là bao nhiêu?
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2021/BVH/THPT.csv')
q22 = ""
a22 = ""

q = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2021 tại cơ sở miền bắc?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2021 tại cơ sở miền bắc là:\n"

for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " năm 2021 là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")


    q22 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2021 tại cơ sở miền bắc là bao nhiêu?"
    a22 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2021 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    print(q22)
    print(a22)
    data['question'].append(q22)
    data['answer'].append(a22)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2021 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2021 tại cơ sở miền bắc là 25.65
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2021 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2021 tại cơ sở miền bắc là 25.35
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi thpt năm 2021 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi thpt năm 2021 tại cơ sở miền bắc là 26.9
# Điểm chuẩn ngành an toàn thông tin theo phương thức thi thpt năm 2021 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành an toàn thông tin theo phương thức thi thpt năm 2021 tại cơ sở miền bắc là 26.55
# Điểm chuẩn ngành công nghệ đa phương tiện theo phương thức thi thpt năm 2021 tại cơ sở miền bắc là bao nhiêu?
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2024/BVH/THPT.csv')
q22 = ""
a22 = ""

q = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2024 tại cơ sở miền bắc?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2024 tại cơ sở miền bắc là:\n"

for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")

    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " năm 2024 là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")


    q22 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2024 tại cơ sở miền bắc là bao nhiêu?"
    a22 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2024 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    print(q22)
    print(a22)
    data['question'].append(q22)
    data['answer'].append(a22)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2024 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2024 tại cơ sở miền bắc là 25.75
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2024 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2024 tại cơ sở miền bắc là 25.46
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi thpt năm 2024 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi thpt năm 2024 tại cơ sở miền bắc là 26.08
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi thpt năm 2024 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi thpt năm 2024 tại cơ sở miền bắc là 26.4
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2023/BVS/THPT.csv')
q23 = ""
a23 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2023 tại cơ sở miền nam?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2023 tại cơ sở miền nam là:\n"

for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"
    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " năm 2023 là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")

    q23 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2023 tại cơ sở miền nam là bao nhiêu?"
    a23 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2023 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    print(q23)
    print(a23)
    data['question'].append(q23)
    data['answer'].append(a23)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2023 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2023 tại cơ sở miền nam là 21.9
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2023 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2023 tại cơ sở miền nam là 18.15
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi thpt năm 2023 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi thpt năm 2023 tại cơ sở miền nam là 18.0
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức thi thpt năm 2023 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức thi thpt năm 2023 tại cơ sở miền nam là 21.7
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2022/BVS/THPT.csv')
q24 = ""
a24 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2022 tại cơ sở miền nam?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2022 tại cơ sở miền nam là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"
    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " năm 2022 là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")

    q24 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2022 tại cơ sở miền nam là bao nhiêu?"
    a24 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2022 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    print(q24)
    print(a24)
    data['question'].append(q24)
    data['answer'].append(a24)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2022 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2022 tại cơ sở miền nam là 21.0
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức thi thpt năm 2022 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức thi thpt năm 2022 tại cơ sở miền nam là 20.7
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2022 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2022 tại cơ sở miền nam là 19.0
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi thpt năm 2022 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi thpt năm 2022 tại cơ sở miền nam là 19.05
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2021/BVS/THPT.csv')
q25 = ""
a25 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2021 tại cơ sở miền nam?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2021 tại cơ sở miền nam là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"
    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " năm 2021 là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")

    q25 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2021 tại cơ sở miền nam là bao nhiêu?"
    a25 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2021 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    print(q25)
    print(a25)
    data['question'].append(q25)
    data['answer'].append(a25)
    data['tag'].append("điểm")


data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2021 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2021 tại cơ sở miền nam là 22.7
# Điểm chuẩn ngành công nghệ kt điện, điện tử theo phương thức thi thpt năm 2021 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ kt điện, điện tử theo phương thức thi thpt năm 2021 tại cơ sở miền nam là 19.3
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi thpt năm 2021 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi thpt năm 2021 tại cơ sở miền nam là 19.4
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi thpt năm 2021 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi thpt năm 2021 tại cơ sở miền nam là 25.9
# Điểm chuẩn ngành an toàn thông tin theo phương thức thi thpt năm 2021 tại cơ sở miền nam là bao nhiêu?
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2024/BVS/THPT.csv')
q25 = ""
a25 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2024 tại cơ sở miền nam?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi thpt 2024 tại cơ sở miền nam là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"
    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")

    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " năm 2024 là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")

    q25 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2024 tại cơ sở miền nam là bao nhiêu?"
    a25 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi thpt năm 2024 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    print(q25)
    print(a25)
    data['question'].append(q25)
    data['answer'].append(a25)
    data['tag'].append("điểm")


data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2024 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi thpt năm 2024 tại cơ sở miền nam là 23.23
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2024 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi thpt năm 2024 tại cơ sở miền nam là 20.85
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi thpt năm 2024 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi thpt năm 2024 tại cơ sở miền nam là 19.65
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức thi thpt năm 2024 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức thi thpt năm 2024 tại cơ sở miền nam là 18.0
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2024/BVH/DGNL.csv')
q26 = ""
a26 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức thi đánh giá năng lực, đánh giá tư duy năm 2024 tại cơ sở miền bắc?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi đánh giá năng lực, đánh giá tư duy năm 2024 tại cơ sở miền bắc là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " năm 2024 là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")

    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")
    
    q26 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền bắc là bao nhiêu?"
    a26 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    print(q26)
    print(a26)
    data['question'].append(q26)
    data['answer'].append(a26)
    data['tag'].append("điểm")

    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá tư duy năm 2024 tại cơ sở miền bắc là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá tư duy năm 2024 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền bắc là 20.65
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền bắc là 22.05
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền bắc là 19.84
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền bắc là bao nhiêu?
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2023/BVH/DGNL.csv')
q26 = ""
a26 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức thi đánh giá năng lực, đánh giá tư duy năm 2023 tại cơ sở miền bắc?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi đánh giá năng lực, đánh giá tư duy năm 2023 tại cơ sở miền bắc là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"
    q111 = "Điểm chuẩn của ngành " + df['Tên ngành'].iloc[i].lower() + " năm 2024 là bao nhiêu?"
    a111 = "Bạn muốn hỏi điểm chuẩn dựa trên phương thức xét tuyển nào, cơ sở miền bắc hay nam? Ví dụ về phương thức xét tuyển như xét tuyển kết hợp, thi thpt, đánh giá năng lực, đánh giá tư duy."
    data['question'].append(q111)
    data['answer'].append(a111)
    data['tag'].append("điểm")

    q26 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền bắc là bao nhiêu?"
    a26 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    print(q26)
    print(a26)
    data['question'].append(q26)
    data['answer'].append(a26)
    data['tag'].append("điểm")


    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá tư duy năm 2023 tại cơ sở miền bắc là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá tư duy năm 2023 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")


data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền bắc là 16.0
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền bắc là 16.45
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền bắc là 20.05
# Điểm chuẩn ngành an toàn thông tin theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành an toàn thông tin theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền bắc là 18.85
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2022/BVH/DGNL.csv')
q26 = ""
a26 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức thi đánh giá năng lực, đánh giá tư duy năm 2022 tại cơ sở miền bắc?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi đánh giá năng lực, đánh giá tư duy năm 2022 tại cơ sở miền bắc là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q26 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền bắc là bao nhiêu?"
    a26 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    print(q26)
    print(a26)
    data['question'].append(q26)
    data['answer'].append(a26)
    data['tag'].append("điểm")


    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá tư duy năm 2022 tại cơ sở miền bắc là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá tư duy năm 2022 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền bắc là 19.45
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền bắc là 19.3
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền bắc là 21.5
# Điểm chuẩn ngành an toàn thông tin theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành an toàn thông tin theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền bắc là 20.65
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2024/BVS/DGNL.csv')
q26 = ""
a26 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức thi đánh giá năng lực, đánh giá tư duy năm 2024 tại cơ sở miền nam?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi đánh giá năng lực, đánh giá tư duy năm 2024 tại cơ sở miền nam là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q26 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền nam là bao nhiêu?"
    a26 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    print(q26)
    print(a26)
    data['question'].append(q26)
    data['answer'].append(a26)
    data['tag'].append("điểm")

    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá tư duy năm 2024 tại cơ sở miền nam là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá tư duy năm 2024 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền nam là 16.23
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền nam là 15.08
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền nam là 16.18
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức thi đánh giá năng lực năm 2024 tại cơ sở miền nam là bao nhiêu?
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2023/BVS/DGNL.csv')
q26 = ""
a26 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức thi đánh giá năng lực, đánh giá tư duy năm 2023 tại cơ sở miền nam?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi đánh giá năng lực, đánh giá tư duy năm 2023 tại cơ sở miền nam là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q26 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền nam là bao nhiêu?"
    a26 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    print(q26)
    print(a26)
    data['question'].append(q26)
    data['answer'].append(a26)
    data['tag'].append("điểm")

    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá tư duy năm 2023 tại cơ sở miền nam là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá tư duy năm 2023 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền nam là 19.18
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền nam là 16.5
# Điểm chuẩn ngành công nghệ internet vạn vật theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ internet vạn vật theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền nam là 18.93
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi đánh giá năng lực năm 2023 tại cơ sở miền nam là 17.1
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2022/BVS/DGNL.csv')
q26 = ""
a26 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức thi đánh giá năng lực, đánh giá tư duy năm 2022 tại cơ sở miền nam?"
a = "Điểm chuẩn tất cả các ngành theo phương thức thi đánh giá năng lực, đánh giá tư duy năm 2022 tại cơ sở miền nam là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q26 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền nam là bao nhiêu?"
    a26 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    print(q26)
    print(a26)
    data['question'].append(q26)
    data['answer'].append(a26)
    data['tag'].append("điểm")

    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá tư duy năm 2022 tại cơ sở miền nam là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức thi đánh giá tư duy năm 2022 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền nam là 19.63
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền nam là 18.4
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền nam là 19.93
# Điểm chuẩn ngành công nghệ thông tin theo phương thức thi đánh giá năng lực năm 2022 tại cơ sở miền nam là bao nhiêu?
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2024/BVH/XTKH.csv')
q27 = ""
a27 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền bắc?"
q1 = "Điểm chuẩn tất cả các ngành theo xét tuyển kết hợp năm 2024 tại cơ sở miền bắc?"

a = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền bắc là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền bắc là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    print(q27)
    print(a27)
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền bắc là 26.42
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền bắc là 27.71
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền bắc là 25.07
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền bắc là 27.01
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2023/BVH/XTKH.csv')
q27 = ""
a27 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền bắc?"
q1 = "Điểm chuẩn tất cả các ngành xét tuyển kết hợp năm 2023 tại cơ sở miền bắc?"

a = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền bắc là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền bắc là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    print(q27)
    print(a27)
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền bắc là 22.36
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền bắc là 21.2
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền bắc là 28.03
# Điểm chuẩn ngành an toàn thông tin theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành an toàn thông tin theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền bắc là 27.43
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2022/BVH/XTKH.csv')
q27 = ""
a27 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền bắc?"
q1 = "Điểm chuẩn tất cả các ngành xét tuyển kết hợp năm 2022 tại cơ sở miền bắc?"

a = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền bắc là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"
    
    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền bắc là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    print(q27)
    print(a27)
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền bắc là 22.6
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền bắc là 22.5
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền bắc là 27.97
# Điểm chuẩn ngành an toàn thông tin theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành an toàn thông tin theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền bắc là 27.06
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2021/BVH/XTKH.csv')
q27 = ""
a27 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền bắc?"
q1= "Điểm chuẩn tất cả các ngành xét tuyển kết hợp năm 2021 tại cơ sở miền bắc?"

a = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền bắc là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền bắc là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền bắc là " + str(df['Điểm chuẩn'].iloc[i])
    print(q27)
    print(a27)
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền bắc là 25.32
# Điểm chuẩn ngành công nghệ kt điện, điện tử theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ kt điện, điện tử theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền bắc là 23.58
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền bắc là 27.44
# Điểm chuẩn ngành an toàn thông tin theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền bắc là bao nhiêu?
# Điểm chuẩn ngành an toàn thông tin theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền bắc là 27.21
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2024/BVS/XTKH.csv')
q27 = ""
a27 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền nam?"
q1 = "Điểm chuẩn tất cả các ngành xét tuyển kết hợp năm 2024 tại cơ sở miền nam?"

a = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền nam là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền nam là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    print(q27)
    print(a27)
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")
data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền nam là 23.77
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ kỹ thuật điện, điện tử theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền nam là 24.36
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền nam là 23.7
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức xét tuyển kết hợp năm 2024 tại cơ sở miền nam là bao nhiêu?
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2023/BVS/XTKH.csv')
q27 = ""
a27 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền nam?"
q1 = "Điểm chuẩn tất cả các ngành xét tuyển kết hợp năm 2023 tại cơ sở miền nam?"

a = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền nam là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền nam là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    print(q27)
    print(a27)
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền nam là 23.11
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền nam là 26.46
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền nam là 22.82
# Điểm chuẩn ngành an toàn thông tin theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành an toàn thông tin theo phương thức xét tuyển kết hợp năm 2023 tại cơ sở miền nam là 24.04
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2022/BVS/XTKH.csv')
q27 = ""
a27 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền nam?"
q1 = "Điểm chuẩn tất cả các ngành xét tuyển kết hợp năm 2022 tại cơ sở miền nam?"

a = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền nam là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền nam là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    print(q27)
    print(a27)
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")


data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền nam là 22.93
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền nam là 27.41
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ internet vạn vật (iot) theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền nam là 25.48
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2022 tại cơ sở miền nam là 22.77
# ...

# %%
import pandas as pd

# Đọc file JSON
df = pd.read_csv('documents/score/2021/BVS/XTKH.csv')
q27 = ""
a27 = ""
q = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền nam?"
q1 = "Điểm chuẩn tất cả các ngành xét tuyển kết hợp năm 2021 tại cơ sở miền nam?"

a = "Điểm chuẩn tất cả các ngành theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền nam là:\n"


for i in range(len(df)):
    a = a + df['Tên ngành'].iloc[i].lower().capitalize() + ": " + str(df['Điểm chuẩn'].iloc[i]) + "\n"

    q27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền nam là bao nhiêu?"
    a27 = "Điểm chuẩn ngành " + df['Tên ngành'].iloc[i].lower() + " theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền nam là " + str(df['Điểm chuẩn'].iloc[i])
    print(q27)
    print(a27)
    data['question'].append(q27)
    data['answer'].append(a27)
    data['tag'].append("điểm")

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")

data['question'].append(q1)
data['answer'].append(a.rstrip())
data['tag'].append("điểm")



data_frame = pd.DataFrame(data)
data_frame
# Out:
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điện tử viễn thông theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền nam là 22.6
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành công nghệ thông tin theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền nam là 24.2
# Điểm chuẩn ngành an toàn thông tin theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành an toàn thông tin theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền nam là 23.4
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền nam là bao nhiêu?
# Điểm chuẩn ngành kỹ thuật điều khiển và tự động hóa theo phương thức xét tuyển kết hợp năm 2021 tại cơ sở miền nam là 23.78
# ...

# %%
years = ['2021','2022','2023','2024']
methods = ["phương thức thi thpt","xét tuyển kết hợp","phương thức thi đánh giá năng lực","phương thức thi đánh giá tư duy"]
for method in methods:
    for year in years:
        q = "Điểm chuẩn ngành công nghệ internet vạn vật năm " + year + " theo " + method + " tại cơ sở miền bắc là bao nhiêu?"
        a = "Cơ sở miền bắc của Học Viện không đào tạo ngành IoT"
        data['question'].append(q)
        data['answer'].append(a.rstrip())
        data['tag'].append("điểm")


    q1 = "Chỉ tiêu ngành công nghệ internet vạn vật năm 2024"  + " theo " + method + " tại cơ sở miền bắc là bao nhiêu?"
    a1 = "Cơ sở miền bắc của Học Viện không đào tạo ngành IoT"
    data['question'].append(q1)
    data['answer'].append(a1.rstrip())
    data['tag'].append("ngành đào tạo")
    

data_frame = pd.DataFrame(data)
data_frame
# Out:
#                                                question  \
# 0     Nguyên tắc xét tuyển của học viện năm nay ntn?...
# 1                      Câu hỏi thường gặp về tuyển sinh
# 2     Chương trình đào tạo tại miền Nam có khác với ...
# 3     Trường mình có 2 cơ sở, vậy sẽ phân bố học sin...
# 4     Em đăng ký NV1 là ngành An toàn thông tin, NV2...
# ...                                                 ...
# 1231  Điểm chuẩn ngành công nghệ internet vạn vật nă...
# 1232  Điểm chuẩn ngành công nghệ internet vạn vật nă...
# 1233  Điểm chuẩn ngành công nghệ internet vạn vật nă...
# 1234  Điểm chuẩn ngành công nghệ internet vạn vật nă...
# 1235  Chỉ tiêu ngành công nghệ internet vạn vật năm ...
#
#                                                  answer            tag
# 0     I. Xét tuyển dựa vào kết quả thi THPT 2024:\n-...     tuyển sinh
# 1                               Bạn đang gặp vấn đề gì?     tuyển sinh
# 2     Chương trình đào tạo của Học viện được áp dụng...     tuyển sinh
# ...

# %% [markdown]
# Q&A other

# %%
import pandas as pd
q = "Những câu hỏi liên quan đến hình ảnh"
a = "Hiện tại chatbot không thể tạo ra được ảnh. Bạn vui lòng đặt câu hỏi khác."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học viện")


q = "Những câu hỏi liên quan đến cảm ơn"
a = "Tôi rất vui khi có thể giúp được bạn. Nếu bạn còn câu hỏi hay thắc mắc nào thì hãy cứ hỏi nhé. Chúc bạn một ngày tốt lành! 💖"
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học viện")

# %%
q = "Học viện có bao nhiêu phương thức tuyển sinh"
a = "Học viện có 4 phương thức tuyển sinh là xét tuyển kết hợp, thi thpt quốc gia, xét tuyển tài năng và thi đánh giá năng lực, tư duy."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("tuyển sinh")

q = "chào bạn! Bạn có thể giúp tôi không"
a = "Tôi có thể giúp gì được cho bạn?"
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("chào hỏi")

q = "chào bạn!"
a = "Tôi có thể giúp gì được cho bạn?"
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("chào hỏi")

q = "Hello!"
a = "Tôi có thể giúp gì được cho bạn?"
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("chào hỏi")

q = "Hi!"
a = "Tôi có thể giúp gì được cho bạn?"
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("chào hỏi")


q = "Bạn là ai?"
a = "Tôi là chatbot hỗ trợ trả lời các câu hỏi liên quan đến tuyển sinh của Học Viện."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("chào hỏi")

q = "Học phí chương trình đại trà là bao nhiêu"
a = " Học phí trình độ đại học hệ chính quy chương trình đại trà năm học 2024-2025: từ 27 triệu đồng đến 34 triệu đồng/năm tùy theo ngành học."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học phí")

q = "Học phí bình thường là bao nhiêu"
a = " Học phí trình độ đại học hệ chính quy chương trình đại trà năm học 2024-2025: từ 27 triệu đồng đến 34 triệu đồng/năm tùy theo ngành học. Học phí chương trình chất lượng cao năm học 2024-2025: từ 39 triệu đồng đến 55 triệu đồng/năm tùy theo ngành học."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học phí")

q = "Học phí chất lượng thường là bao nhiêu"
a = " Học phí trình độ đại học hệ chính quy chương trình đại trà năm học 2024-2025: từ 27 triệu đồng đến 34 triệu đồng/năm tùy theo ngành học."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học phí")

q = "Học phí chất lượng cao là bao nhiêu"
a = "Học phí chương trình chất lượng cao năm học 2024-2025: từ 39 triệu đồng đến 55 triệu đồng/năm tùy theo ngành học."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học phí")

q = "Chất lượng cao có học phí như nào"
a = "Học phí chương trình chất lượng cao năm học 2024-2025: từ 39 triệu đồng đến 55 triệu đồng/năm tùy theo ngành học."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học phí")
q = "Làm sao để kiếm người yêu khi học đại học"
a = '''Việc tìm kiếm người yêu khi đang học đại học có thể là một trải nghiệm thú vị, nhưng đôi khi cũng có thể gặp khó khăn. Đây là vài gợi ý:
1. Tham gia các hoạt động ngoại khóa: Tham gia câu lạc bộ, tổ chức hoặc các hoạt động ngoại khóa khác giúp bạn gặp gỡ nhiều người mới, có cơ hội tìm kiếm những người có sở thích chung.

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("địa chỉ")

q = "Trụ sở quản lý của học viện ở đâu"
a = "Bạn muốn hỏi địa chỉ ở cơ sở miền bắc hay miền nam của học viện."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("địa chỉ")

q = "Trụ sở quản lý của học viện tại cơ sở miền bắc ở đâu"
a = "Địa chỉ: 122 đường Hoàng Quốc Việt, Phường Nghĩa Tân, Quận Cầu Giấy, Thành phố Hà Nội."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("địa chỉ")

q = "Trụ sở quản lý của học viện tại cơ sở miền nam ở đâu"
a = "Địa chỉ: 11 đường Nguyễn Đình Chiểu, Phường Đa Kao, Quận 1, Thành phố Hồ Chí Minh."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("địa chỉ")

q = "Cơ sở đào tạo của học viện ở đâu"
a = "Bạn muốn hỏi địa chỉ ở cơ sở miền bắc hay miền nam của học viện."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("địa chỉ")

q = "Cơ sở đào tạo của học viện tại cơ sở miền bắc ở đâu"
a = "Địa chỉ: Km10, đường Nguyễn Trãi, Phường Mộ Lao, Quận Hà Đông, Thành phố Hà Nội."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("địa chỉ")

q = "Cơ sở đào tạo của học viện tại cơ sở miền nam ở đâu"
a = "Địa chỉ: 97 đường Man Thiện, Thành phố Thủ Đức, Thành phố Hồ Chí Minh."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("địa chỉ")

q = "Trụ sở chính của học viện ở đâu"
a = "Trụ sở chính của học viện nằm ở 122 đường Hoàng Quốc Việt, Phường Nghĩa Tân, Quận Cầu Giấy, Thành phố Hà Nội."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("địa chỉ")

q = "Học tại học viện có nhàn không?"
a = "Nhàn hay không tùy bản thân bạn. Bạn chăm học thì NHÀN."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học viện")

q = "Vào học viện có người yêu không?"
a = "Vào học viện auto có người yêu bạn nhé!"
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học viện")

q = "Cơ sở vật chất của học viện như nào?"
a = "Cơ sở vật chất của học viện xứng danh với học viện hoàng gia."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học viện")

q = "Học viện học xong có việc không?"
a = "Bạn đáp ứng đủ chuẩn đầu ra của học viện thì dễ có việc nhé!"
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học viện")

q = "Vừa học vừa làm có đủ thời gian không?"
a = "Đủ nếu bạn sắp xếp được thời gian hợp lý."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học viện")

q = "Ăn uống, sinh hoạt ở học viện như nào?"
a = "Trong học viện có căng tin, bên cạnh học viện thì có thiên đường ăn vặt Ao Sen nhé."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học viện")

q = "Những ngành học mới trong học viện?"
a = "Bạn muốn hỏi ngành mới năm nay của học viện ở cơ sở miền bắc hay miền nam."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")

q = "Những ngành học mới trong học viện năm 2024?"
a = "Bạn muốn hỏi ngành mới của học viện ở cơ sở miền bắc hay miền nam."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")

q = "Những ngành học mới trong học viện năm 2024 tại cơ sở miền bắc?"
a = '''Cơ sở miền bắc có đào tạo thêm các ngành mới so với năm trước là:
1.Ngành quan hệ công chúng (Ngành Marketing)
2.Thiết kế và phát triển Game (Ngành Công nghệ đa phương tiện)
3.Công nghệ thông tin Việt Nhật
Những ngành học này được thiết kế để đáp ứng như cầu ngày càng cao của thị học viện lao động và xu hướng công nghệ hiện đại.
'''
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")

q = "Miền bắc đào tạo những ngành mới nào năm 2024?"
a = '''Cơ sở miền bắc có đào tạo thêm các ngành mới so với năm trước là:
1.Ngành quan hệ công chúng (Ngành Marketing)
2.Thiết kế và phát triển Game (Ngành Công nghệ đa phương tiện)
3.Công nghệ thông tin Việt Nhật
Những ngành học này được thiết kế để đáp ứng như cầu ngày càng cao của thị học viện lao động và xu hướng công nghệ hiện đại.
'''
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")

q = "

data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("tuyển sinh")

q = "Cho mình hỏi là có cần nộp giấy giới thiệu di chuyển đăng ký nghĩa vụ quân sự cho học viện không ạ?"
a = "Phải nộp giấy di chuyển đăng ký nghĩa vụ quân sự cùng hồ sơ nhập học trong ngày nhập học bạn nhé!"
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("tuyển sinh")

q = "Mình đóng tiền có cần ghi nội dung không ạ?"
a = "Bạn không cần phải ghi nội dung chuyển khoản vì mỗi người đã được gán 1 mã thanh toán riêng rồi."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("tuyển sinh")

q = "Mình muốn đăng ký ký túc xá thì như nào?"
a = "Bạn đăng ký ký túc xá trong ngày nhập học luôn nhé! Liên hệ với ban quản lý của ký túc xá để làm việc."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học viện")

q = "Cho em hỏi học viện đóng dấu chuyển cơ sở đoàn về xã xong mình có phải ra xã chuyển về học viện ko ạ?"
a = "Cần học viện đóng dấu là được em nhé!"
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("tuyển sinh")

q = "Quy định, quy chế tuyển sinh của học viện?"
a = """Quy chế 1: Xét tuyển theo ngành và theo tổ hợp môn thi xét tuyển.
Quy chế 2: Điểm trúng tuyển của các tổ hợp môn thi trong cùng một ngành là bằng nhau.
Quy chế 3: Xét trúng tuyển từ thí sinh có kết quả cao xuống và đảm bảo chất lượng tuyển sinh.
Quy chế 4: Điểm trúng tuyển được tính theo thang điểm 10, tổng điểm tối đa của 3 bài thi trong tổ hợp xét tuyển là 30 điểm.
Quy chế 5: Xét tuyển các nguyện vọng bình đẳng theo kết quả thi (điểm trúng tuyển giữa các nguyện vọng là bằng nhau), nếu thí sinh không trúng tuyển nguyện vọng ở thứ tự ưu tiên thứ nhất (nguyện vọng 1) thì sẽ được tự động xét tuyển ở nguyện vọng ưu tiên thứ hai (nguyện vọng 2) và kế tiếp.
Quy chế 6: Học viện không sử dụng kết quả miễn thi bài thi môn ngoại ngữ và điểm thi được bảo lưu để xét tuyển.
Quy chế 7: Thí sinh chỉ trúng tuyển vào 1 nguyện vọng ưu tiên cao nhất trong danh sách các nguyện vọng đã đăng ký, khi đã trúng tuyển ở nguyện vọng nào thì không được xét tuyển tiếp ở nguyện vọng sau.
Quy chế 8: Đối với các thí sinh bằng điểm xét tuyển ở cuối danh sách, nếu vẫn còn vượt chỉ tiêu thì ưu tiên thí sinh có nguyện vọng cao hơn theo Quy chế tuyển sinh của Bộ Giáo dục và Đào tạo, Học viện không sử dụng tiêu chí phụ riêng để xét tuyển.
Quy chế 9: Các điều kiện khác thực hiện theo Quy chế tuyển sinh đại học hệ chính quy hiện hành của Bộ Giáo dục và Đào tạo.
"""
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("tuyển sinh")

q = "Tôi yêu thích bảo mật thì nên học ngành nào?"
a = "Bạn yêu thích bảo mật thì ngành phù hợp với bạn nhất là ngành An toàn thông tin. Ngành này cung cấp cho sinh viên những kiến thức chuyên sâu về bảo mật thông tin và an ninh mạng."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("ngành đào tạo")

q = "Các phương thức đào tạo tại học viện?"
a = "Hiện tại học viện đang đào tạo các phương thức như đại học chính quy, đào tạo sau đại học, hệ vừa học vừa làm và hệ từ xa."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("tuyển sinh")

q = "Học viện đào tạo các phương thức nào?"
a = "Hiện tại học viện đang đào tạo các phương thức như đại học chính quy, đào tạo sau đại học, hệ vừa học vừa làm và hệ từ xa."
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("tuyển sinh")

q = "
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học viện")

q = "Ý nghĩa logo của học viện?"
a = """Hình khối của logo
Logo của Học viện thể hiện hình ảnh cô đọng nhất về Học viện. Khối Logo của Học viện bao gồm hình tròn và hình vuông. Theo quan niệm Á Đông, hình tròn tượng trưng cho sự sinh tồn vĩnh cửu của tự nhiên, nói lên sự đầy đủ, thịnh vượng và phát triển. Cũng theo ý nghĩa triết học Phương Đông, logo Học viện thể hiện mối quan hệ cơ bản: Thiên (tròn) – Địa (vuông) – Nhân (Học viện); trong đó Học viện là trung tâm. Cấu trúc logo mở thể hiện Học viện gắn liền với thực tiễn, với xã hội và luôn phát triển không ngừng. Ba vòng tròn quyện vào nhau và chuyển hóa sang nhau thể hiện 3 gắn kết: Đào tạo – Nghiên cứu – Sản xuất Kinh doanh. Hình ảnh quyển sách mở rộng và mô hình cấu trúc nguyên tử: biểu tượng 2 hoạt động chính của Học viện là đào tạo và nghiên cứu Chữ PTIT (tên viết tắt tiếng Anh của Học viện – Posts & Telecoms Institute of Technology) đồng thời là Bưu chính (P), Viễn thông (T) và Công nghệ thông tin (IT) – 3 lĩnh vực nghiên cứu và đào tạo của Học viện
Màu sắc logo
Logo Học viện lấy màu đỏ làm chủ đạo và ngôi sao vàng biểu trưng cho cờ Tổ quốc Việt Nam."""
data['question'].append(q)
data['answer'].append(a.rstrip())
data['tag'].append("học viện")


data_frame = pd.DataFrame(data)
data_frame
# Out:
#                                                question  \
# 0     Nguyên tắc xét tuyển của học viện năm nay ntn?...
# 1                      Câu hỏi thường gặp về tuyển sinh
# 2     Chương trình đào tạo tại miền Nam có khác với ...
# 3     Trường mình có 2 cơ sở, vậy sẽ phân bố học sin...
# 4     Em đăng ký NV1 là ngành An toàn thông tin, NV2...
# ...                                                 ...
# 1378              Sinh viên có thể thực tập từ năm mấy?
# 1379     Các doanh nghiệp thường liên kết với học viện?
# 1380  Làm sao để tham gia các buổi tư vấn nghề nghiệ...
# 1381  Làm sao để tham gia các buổi tư vấn nghề nghiệ...
# 1382                         Ý nghĩa logo của học viện?
#
#                                                  answer         tag
# 0     I. Xét tuyển dựa vào kết quả thi THPT 2024:\n-...  tuyển sinh
# 1                               Bạn đang gặp vấn đề gì?  tuyển sinh
# 2     Chương trình đào tạo của Học viện được áp dụng...  tuyển sinh
# ...

# %%
import pandas as pd

df = pd.read_excel('data/data.xlsx', sheet_name='data')


# Gộp với DataFrame chính nếu cần
data_frame = pd.concat([data_frame, df], ignore_index=True)
data_frame
# Out:
#                                                question  \
# 0     Nguyên tắc xét tuyển của học viện năm nay ntn?...
# 1                      Câu hỏi thường gặp về tuyển sinh
# 2     Chương trình đào tạo tại miền Nam có khác với ...
# 3     Trường mình có 2 cơ sở, vậy sẽ phân bố học sin...
# 4     Em đăng ký NV1 là ngành An toàn thông tin, NV2...
# ...                                                 ...
# 1496  Bí thư Chi đoàn được nhận bao nhiêu tiền một t...
# 1497        Lớp phó được nhận bao nhiêu tiền một tháng?
# 1498               Điểm rèn luyện được tính như thế nào
# 1499  Để đạt loại tốt điểm rèn luyện cần bao nhiêu đ...
# 1500  Để đạt loại xuất sắc điểm rèn luyện cần bao nh...
#
#                                                  answer         tag
# 0     I. Xét tuyển dựa vào kết quả thi THPT 2024:\n-...  tuyển sinh
# 1                               Bạn đang gặp vấn đề gì?  tuyển sinh
# 2     Chương trình đào tạo của Học viện được áp dụng...  tuyển sinh
# ...

# %%
additional_data = {
    "question": [
        "Thời gian nộp hồ sơ tuyển sinh là khi nào?",
        "Điều kiện tuyển sinh vào học viện là gì?",
        "Có cần thi đầu vào tiếng anh không?",
        "Học viện có chương trình học bổng không?",
        "Thời gian đào tạo cho mỗi ngành là bao lâu?",
        "Các hình thức xét tuyển là gì?",
        "Học phí của các ngành học là bao nhiêu?",
        "Học phí của các ngành học ở Học Viện là bao nhiêu?",
        "Học viện có cơ sở vật chất như thế nào?",
        "Có chương trình thực tập cho sinh viên không?",
        "Sinh viên có thể làm gì sau khi tốt nghiệp?",
        "Có thể thay đổi ngành học sau khi nhập học không?",
        "Học viện có tổ chức các hoạt động ngoại khóa không?",
        "Có thể đăng ký trực tuyến không?",
        "Thời gian mở lớp học là khi nào?",
        "Thời gian bắt đầu kỳ học mới là khi nào?",
        "Có tư vấn hướng nghiệp cho sinh viên không?",
        "Các giảng viên có trình độ như thế nào?",
        "Có hỗ trợ tìm việc làm cho sinh viên sau khi tốt nghiệp không?",
        "Học viện có liên kết với các doanh nghiệp không?"
    ],
    "answer": [
        "Thời gian nộp hồ sơ tuyển sinh từ khoảng tháng 5 đến tháng 8 hàng năm.",
        "Điều kiện tuyển sinh bao gồm tốt nghiệp THPT và đạt điểm xét tuyển theo quy định.",
        "Có, học viện yêu cầu thi đầu vào tiếng anh cho một số ngành.",
        "Có 3 loại học bổng là: học bổng đặc biệt, học bổng toàn phần và học bổng cho thí sinh đạt thành tích cao",
        "Thời gian đào tạo trung bình cho mỗi ngành là 4 năm.",
        "Có 4 hình thức xét tuyển: xét tuyển dựa trên kết quả thi THPT, xét tuyển tài năng, xét tuyển kết hợp và xét tuyển dựa vào kết quả thi đánh giá năng lực, tư duy.",
        "Học phí tùy theo từng ngành, trung bình khoảng 33.000.000đ đến 35.000.000đ/1 năm cho hệ thường, chất lượng cao > 40.000.000đ/1 năm",
        "Học phí tùy theo từng ngành, trung bình khoảng 33.000.000đ đến 35.000.000đ/1 năm cho hệ thường, chất lượng cao > 40.000.000đ/1 năm",
        "Học viện có cơ sở vật chất hiện đại với phòng lab, thư viện và khu thể thao.",
        "Học viện tổ chức chương trình thực tập tại các doanh nghiệp đối tác.",
        "Sinh viên có thể làm việc trong nhiều lĩnh vực như IT, kinh tế, quản lý, và kỹ thuật.",
        "Sinh viên có thể đăng ký chuyển ngành trong thời gian quy định.",
        "Học viện tổ chức nhiều hoạt động ngoại khóa như câu lạc bộ, hội thảo.",
        "Sinh viên có thể đăng ký trực tuyến thông qua website của học viện.",
        "Lớp học chính thường mở vào giữa tháng 8 hàng năm. Ngoài ra còn có kỳ hè và kỳ đông, bạn có thể đăng ký học lại hoặc học cải thiện trong thời gian này",
        "Lớp học chính thường mở vào giữa tháng 8 hàng năm. Ngoài ra còn có kỳ hè và kỳ đông, bạn có thể đăng ký học lại hoặc học cải thiện trong thời gian này",
        "Học viện có trung tâm tư vấn hướng nghiệp cho sinh viên.",
        "Các giảng viên đều có trình độ thạc sĩ trở lên và nhiều kinh nghiệm giảng dạy.",
        "Học viện hỗ trợ tìm việc làm cho sinh viên thông qua các chương trình kết nối doanh nghiệp.",
        "Học viện có nhiều mối quan hệ với các doanh nghiệp trong và ngoài nước."
    ],
    "tag": [
        "học viện",
        "học viện",
        "học viện",
        "học bổng",
        "ngành đào tạo",
        "tuyển sinh",
        "học phí",
        "học phí",
        "học viện",
        "học viện",
        "học viện",
        "học viện",
        "học viện",
        "học viện",
        "học viện",
        "học viện",
        "học viện",
        "học viện",
        "học viện",
        "học viện",
    ],
}
# Tạo DataFrame từ dữ liệu bổ sung
additional_df = pd.DataFrame(additional_data)

# Gộp với DataFrame chính nếu cần
data_frame = pd.concat([data_frame, additional_df], ignore_index=True)
data_frame
# Out:
#                                                question  \
# 0     Nguyên tắc xét tuyển của học viện năm nay ntn?...
# 1                      Câu hỏi thường gặp về tuyển sinh
# 2     Chương trình đào tạo tại miền Nam có khác với ...
# 3     Trường mình có 2 cơ sở, vậy sẽ phân bố học sin...
# 4     Em đăng ký NV1 là ngành An toàn thông tin, NV2...
# ...                                                 ...
# 1516           Thời gian bắt đầu kỳ học mới là khi nào?
# 1517        Có tư vấn hướng nghiệp cho sinh viên không?
# 1518            Các giảng viên có trình độ như thế nào?
# 1519  Có hỗ trợ tìm việc làm cho sinh viên sau khi t...
# 1520   Học viện có liên kết với các doanh nghiệp không?
#
#                                                  answer         tag
# 0     I. Xét tuyển dựa vào kết quả thi THPT 2024:\n-...  tuyển sinh
# 1                               Bạn đang gặp vấn đề gì?  tuyển sinh
# 2     Chương trình đào tạo của Học viện được áp dụng...  tuyển sinh
# ...

# %%
df_unique = data_frame.drop_duplicates(subset=['question'])
df_unique
# Out:
#                                                question  \
# 0     Nguyên tắc xét tuyển của học viện năm nay ntn?...
# 1                      Câu hỏi thường gặp về tuyển sinh
# 2     Chương trình đào tạo tại miền Nam có khác với ...
# 3     Trường mình có 2 cơ sở, vậy sẽ phân bố học sin...
# 4     Em đăng ký NV1 là ngành An toàn thông tin, NV2...
# ...                                                 ...
# 1516           Thời gian bắt đầu kỳ học mới là khi nào?
# 1517        Có tư vấn hướng nghiệp cho sinh viên không?
# 1518            Các giảng viên có trình độ như thế nào?
# 1519  Có hỗ trợ tìm việc làm cho sinh viên sau khi t...
# 1520   Học viện có liên kết với các doanh nghiệp không?
#
#                                                  answer         tag
# 0     I. Xét tuyển dựa vào kết quả thi THPT 2024:\n-...  tuyển sinh
# 1                               Bạn đang gặp vấn đề gì?  tuyển sinh
# 2     Chương trình đào tạo của Học viện được áp dụng...  tuyển sinh
# ...

# %%
# Lưu DataFrame thành file CSV
df_unique.to_csv('data/questions_answers.csv', index=False)

print("File CSV đã được cập nhật thành công!")
# Out:
# File CSV đã được cập nhật thành công!
